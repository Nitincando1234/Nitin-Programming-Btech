# %%
import matplotlib.pyplot as plt

time_dict = {
    0: 0.000001,
    5000: 0.000547,
    10000: 0.001170,
    15000: 0.001804,
    20000: 0.002482,
    25000: 0.003114,
    30000: 0.003797,
    35000: 0.004589,
    40000: 0.005286,
    45000: 0.006029,
    50000: 0.006799,
    55000: 0.007499,
    60000: 0.008368,
    65000: 0.009021,
    70000: 0.009741,
    75000: 0.010501,
    80000: 0.011245,
    85000: 0.011957,
    90000: 0.012891,
    95000: 0.013499,
    100000: 0.014324
}

# %%
time = time_dict.values()
count = time_dict.keys()
plt.plot(count, time, color = "b")
plt.title("Time(seconds) v.s Input size")
plt.show()

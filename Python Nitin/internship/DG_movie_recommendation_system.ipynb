# %%
#!wget https://files.grouplens.org/datasets/movielens/ml-latest.zip
#!unzip ml-latest.zip
##Run Only if the data not exists in your current runtime

# %%
import pandas as pd

# %%
movies= pd.read_csv('/content/ml-latest/movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(f"shape of our movies.csv: {movies.shape}")
print(movies['genres'].unique())
# Out:
# shape of our movies.csv: (86537, 3)
# ['Adventure|Animation|Children|Comedy|Fantasy'
#  'Adventure|Children|Fantasy' 'Comedy|Romance' ...
#  'Animation|Children|Comedy|Fantasy|Romance'
#  'Comedy|Horror|Mystery|Sci-Fi|Thriller'
#  'Action|Adventure|Drama|Horror|Mystery|Thriller']

# %%
ratings=pd.read_csv('/content/ml-latest/ratings.csv')
ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        1     4.0  1225734739
# 1       1      110     4.0  1225865086
# 2       1      158     4.0  1225733503
# 3       1      260     4.5  1225735204
# 4       1      356     5.0  1225735119

# %%
print(f"shape of our ratings.csv: {ratings.shape}")
print(ratings['userId'].nunique())
print(ratings['movieId'].nunique())
# Out:
# shape of our ratings.csv: (33832162, 4)
# 330975
# 83239

# %%
links= pd.read_csv('/content/ml-latest/links.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags= pd.read_csv('/content/ml-latest/tags.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print("Links: ",links.columns)
print("Tags: ",tags.columns)
print("Movies: ",movies.columns)
print("Ratings: ",ratings.columns)
# Out:
# Links:  Index(['movieId', 'imdbId', 'tmdbId'], dtype='object')
# Tags:  Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')
# Movies:  Index(['movieId', 'title', 'genres'], dtype='object')
# Ratings:  Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
links.describe()
# Out:
#              movieId        imdbId        tmdbId
# count   86537.000000  8.653700e+04  8.641100e+04
# mean   155932.817096  2.696384e+06  2.363101e+05
# std     78037.145347  4.078415e+06  2.404829e+05
# min         1.000000  1.000000e+00  2.000000e+00
# 25%    111443.000000  9.381100e+04  4.632800e+04
# 50%    164574.000000  4.845620e+05  1.362170e+05
# 75%    211225.000000  3.775202e+06  3.762850e+05
# max    288983.000000  2.822749e+07  1.147612e+06
